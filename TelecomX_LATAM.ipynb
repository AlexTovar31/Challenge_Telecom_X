# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexTovar31/Challenge_Telecom_X/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import requests
import json

# %%
url = ('https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json')

# %%
response = requests.get(url)
data = response.json()
telecom = pd.DataFrame(data)

# %%
telecom
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
telecom = pd.json_normalize(data)
telecom.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
#   internet.InternetService  ... internet.OnlineBackup  \
# 0                      DSL  ...                   Yes
# 1                      DSL  ...                    No
# 2              Fiber optic  ...                    No
# 3              Fiber optic  ...                   Yes
# 4              Fiber optic  ...                    No
#
#   internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                        No                  Yes                  Yes
# 1                        No                   No                   No
# 2                       Yes                   No                   No
# 3                       Yes                   No                  Yes
# 4                        No                  Yes                  Yes
#
#   internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                       No         One year                      Yes
# 1                      Yes   Month-to-month                       No
# 2                       No   Month-to-month                      Yes
# 3                      Yes   Month-to-month                      Yes
# 4                       No   Month-to-month                      Yes
#
#   account.PaymentMethod account.Charges.Monthly  account.Charges.Total
# 0          Mailed check                    65.6                  593.3
# 1          Mailed check                    59.9                  542.4
# 2      Electronic check                    73.9                 280.85
# 3      Electronic check                    98.0                1237.85
# 4          Mailed check                    83.9                  267.4
#
# [5 rows x 21 columns]

# %%
telecom.columns
# Out:
# Index(['customerID', 'Churn', 'customer.gender', 'customer.SeniorCitizen',
#        'customer.Partner', 'customer.Dependents', 'customer.tenure',
#        'phone.PhoneService', 'phone.MultipleLines', 'internet.InternetService',
#        'internet.OnlineSecurity', 'internet.OnlineBackup',
#        'internet.DeviceProtection', 'internet.TechSupport',
#        'internet.StreamingTV', 'internet.StreamingMovies', 'account.Contract',
#        'account.PaperlessBilling', 'account.PaymentMethod',
#        'account.Charges.Monthly', 'account.Charges.Total'],
#       dtype='object')

# %%
telecom = pd.json_normalize(data)
telecom.rename(columns={'account.Charges.Monthly': 'Charges_Monthly',
                        'account.Charges.Total': 'Charges_Total'}, inplace=True)
telecom.rename(columns=lambda x: x.split('.')[-1], inplace=True)
telecom.sample(11)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 1152  1635-HDGFT    No  Female              0      No        Yes      19
# 782   1104-FEJAM    No    Male              0     Yes        Yes      28
# 5372  7337-CINUD    No  Female              0     Yes        Yes       8
# 5490  7524-VRLPL    No    Male              1      No         No      69
# 6277  8631-XVRZL    No    Male              0      No         No       9
# 2756  3807-XHCJH    No  Female              0     Yes        Yes       1
# 1037  1452-VOQCH    No    Male              0      No         No       1
# 1061  1485-YDHMM    No    Male              0     Yes        Yes      52
# 3027  4199-QHJNM    No    Male              1     Yes         No      67
# 2832  3930-ZGWVE    No    Male              0      No         No       1
# 2043  2878-RMWXY    No    Male              1     Yes         No      72
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 1152          Yes            No              No  ...  No internet service
# 782           Yes           Yes             DSL  ...                  Yes
# 5372          Yes            No              No  ...  No internet service
# 5490          Yes           Yes             DSL  ...                   No
# 6277          Yes            No              No  ...  No internet service
# 2756          Yes            No              No  ...  No internet service
# 1037          Yes           Yes     Fiber optic  ...                   No
# 1061          Yes           Yes     Fiber optic  ...                  Yes
# 3027          Yes           Yes     Fiber optic  ...                  Yes
# 2832          Yes            No              No  ...  No internet service
# 2043          Yes           Yes     Fiber optic  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 1152  No internet service  No internet service  No internet service
# 782                    No                   No                   No
# 5372  No internet service  No internet service  No internet service
# 5490                  Yes                  Yes                   No
# 6277  No internet service  No internet service  No internet service
# 2756  No internet service  No internet service  No internet service
# 1037                   No                   No                   No
# 1061                   No                  Yes                   No
# 3027                   No                  Yes                  Yes
# 2832  No internet service  No internet service  No internet service
# 2043                  Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 1152  No internet service        Two year               No
# 782                   Yes  Month-to-month               No
# 5372  No internet service        Two year               No
# 5490                  Yes        Two year               No
# 6277  No internet service        One year              Yes
# 2756  No internet service  Month-to-month               No
# 1037                   No  Month-to-month              Yes
# 1061                  Yes  Month-to-month              Yes
# 3027                  Yes        Two year               No
# 2832  No internet service  Month-to-month               No
# 2043                  Yes        Two year              Yes
#
#                   PaymentMethod Charges_Monthly  Charges_Total
# 1152               Mailed check           20.50         398.55
# 782            Electronic check           64.40        1802.15
# 5372  Bank transfer (automatic)           19.50         159.35
# 5490    Credit card (automatic)           74.10           5031
# 6277               Mailed check           20.15          163.7
# 2756           Electronic check           20.00             20
# 1037           Electronic check           75.10           75.1
# 1061  Bank transfer (automatic)           93.25         4631.7
# 3027  Bank transfer (automatic)          102.90         6989.7
# 2832               Mailed check           19.75          19.75
# 2043    Credit card (automatic)          102.65         7550.3
#
# [11 rows x 21 columns]

# %%
telecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges_Monthly   7267 non-null   float64
#  20  Charges_Total     7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
for col in telecom.columns:
    print(f"valores unicos en la columna '{col}':{telecom[col].nunique()}")
    if telecom[col].nunique() < 50:
       print(telecom[col].unique())
       print('-' * 50)
# Out:
# valores unicos en la columna 'customerID':7267
# valores unicos en la columna 'Churn':3
# ['No' 'Yes' '']
# --------------------------------------------------
# valores unicos en la columna 'gender':2
# ['Female' 'Male']
# --------------------------------------------------
# valores unicos en la columna 'SeniorCitizen':2
# [0 1]
# --------------------------------------------------
# valores unicos en la columna 'Partner':2
# ['Yes' 'No']
# --------------------------------------------------
# valores unicos en la columna 'Dependents':2
# ['Yes' 'No']
# --------------------------------------------------
# valores unicos en la columna 'tenure':73
# valores unicos en la columna 'PhoneService':2
# ['Yes' 'No']
# --------------------------------------------------
# valores unicos en la columna 'MultipleLines':3
# ['No' 'Yes' 'No phone service']
# --------------------------------------------------
# valores unicos en la columna 'InternetService':3
# ['DSL' 'Fiber optic' 'No']
# --------------------------------------------------
# valores unicos en la columna 'OnlineSecurity':3
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# valores unicos en la columna 'OnlineBackup':3
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# valores unicos en la columna 'DeviceProtection':3
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# valores unicos en la columna 'TechSupport':3
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# valores unicos en la columna 'StreamingTV':3
# ['Yes' 'No' 'No internet service']
# --------------------------------------------------
# valores unicos en la columna 'StreamingMovies':3
# ['No' 'Yes' 'No internet service']
# --------------------------------------------------
# valores unicos en la columna 'Contract':3
# ['One year' 'Month-to-month' 'Two year']
# --------------------------------------------------
# valores unicos en la columna 'PaperlessBilling':2
# ['Yes' 'No']
# --------------------------------------------------
# valores unicos en la columna 'PaymentMethod':4
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# --------------------------------------------------
# valores unicos en la columna 'Charges_Monthly':1585
# valores unicos en la columna 'Charges_Total':6531

# %%
vacios = telecom.apply(lambda x: x.astype(str).str.strip() =='').sum()
print('\nValores en blanco o string vacios:')
print(vacios[vacios > 0])
# Out:
# Valores en blanco o string vacios:
# Churn            224
# Charges_Total     11
# dtype: int64

# %% [markdown]
# #🔧 Transformación

# %%
import numpy as np

# %% [markdown]
# ##Eliminacion de caracteres especiales y transformacion a tipo float

# %%
telecom['Charges_Total'] = telecom['Charges_Total'].str.replace(',', '').replace('$', '').replace(' ', '').replace('', None)
#Tranformo a float
telecom['Charges_Total'] = telecom['Charges_Total'].astype(np.float64)
#reviso
telecom['Charges_Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Charges_Total
# Non-Null Count  Dtype
# --------------  -----
# 7256 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %%
#identifico por qué están vacías esas filas.
Charges_nulos = telecom['Charges_Total'].isna()
telecom[Charges_nulos]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 975   1371-DWPAZ    No  Female              0     Yes        Yes       0
# 1775  2520-SGTTA    No  Female              0     Yes        Yes       0
# 1955  2775-SEFEE    No    Male              0      No        Yes       0
# 2075  2923-ARZLG    No    Male              0     Yes        Yes       0
# 2232  3115-CZMZD    No    Male              0      No        Yes       0
# 2308  3213-VVOLG    No    Male              0     Yes        Yes       0
# 2930  4075-WKNIU    No  Female              0     Yes        Yes       0
# 3134  4367-NUYAO    No    Male              0     Yes        Yes       0
# 3203  4472-LVYGI    No  Female              0     Yes        Yes       0
# 4169  5709-LVOEQ    No  Female              0     Yes        Yes       0
# 5599  7644-OMVMY    No    Male              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 975            No  No phone service             DSL  ...                  Yes
# 1775          Yes                No              No  ...  No internet service
# 1955          Yes               Yes             DSL  ...                  Yes
# 2075          Yes                No              No  ...  No internet service
# 2232          Yes                No              No  ...  No internet service
# 2308          Yes               Yes              No  ...  No internet service
# 2930          Yes               Yes             DSL  ...                  Yes
# 3134          Yes               Yes              No  ...  No internet service
# 3203           No  No phone service             DSL  ...                   No
# 4169          Yes                No             DSL  ...                  Yes
# 5599          Yes                No              No  ...  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 975                   Yes                  Yes                  Yes
# 1775  No internet service  No internet service  No internet service
# 1955                   No                  Yes                   No
# 2075  No internet service  No internet service  No internet service
# 2232  No internet service  No internet service  No internet service
# 2308  No internet service  No internet service  No internet service
# 2930                  Yes                  Yes                  Yes
# 3134  No internet service  No internet service  No internet service
# 3203                  Yes                  Yes                  Yes
# 4169                  Yes                   No                  Yes
# 5599  No internet service  No internet service  No internet service
#
#           StreamingMovies  Contract PaperlessBilling  \
# 975                    No  Two year               No
# 1775  No internet service  Two year               No
# 1955                   No  Two year              Yes
# 2075  No internet service  One year              Yes
# 2232  No internet service  Two year               No
# 2308  No internet service  Two year               No
# 2930                   No  Two year               No
# 3134  No internet service  Two year               No
# 3203                   No  Two year              Yes
# 4169                  Yes  Two year               No
# 5599  No internet service  Two year               No
#
#                   PaymentMethod Charges_Monthly  Charges_Total
# 975     Credit card (automatic)           56.05            NaN
# 1775               Mailed check           20.00            NaN
# 1955  Bank transfer (automatic)           61.90            NaN
# 2075               Mailed check           19.70            NaN
# 2232               Mailed check           20.25            NaN
# 2308               Mailed check           25.35            NaN
# 2930               Mailed check           73.35            NaN
# 3134               Mailed check           25.75            NaN
# 3203  Bank transfer (automatic)           52.55            NaN
# 4169               Mailed check           80.85            NaN
# 5599               Mailed check           19.85            NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# ##Eliminacion de los datos nulos de la columna Charges_total

# %%
telecom = telecom.drop(telecom[Charges_nulos].index, axis=0)
telecom = telecom.reset_index(drop=True)

# %%
telecom.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod Charges_Monthly  Charges_Total
# 0              Yes      Mailed check            65.6         593.30
# 1               No      Mailed check            59.9         542.40
# 2              Yes  Electronic check            73.9         280.85
# 3              Yes  Electronic check            98.0        1237.85
# 4              Yes      Mailed check            83.9         267.40
#
# [5 rows x 21 columns]

# %% [markdown]
# ##Remplazamos los valores vacios por el No en la columna Churn por que tiene informacion con otras colunas para el analisis.

# %%
churn_nulos = telecom['Churn'].str.strip() == ''

telecom[churn_nulos]
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    0047-ZHDTW        Female              0      No         No      11
# 75    0120-YZLQA          Male              0      No         No      71
# 96    0154-QYHJU          Male              0      No         No      29
# 98    0162-RZGMZ        Female              1      No         No       5
# 175   0274-VVQOQ          Male              1     Yes         No      65
# ...          ...   ...     ...            ...     ...        ...     ...
# 7147  9840-GSRFX        Female              0      No         No      14
# 7169  9872-RZQQB        Female              0     Yes         No      49
# 7200  9920-GNDMB          Male              0      No         No       9
# 7228  9955-RVWSC        Female              0     Yes        Yes      67
# 7236  9966-VYRTZ        Female              0     Yes        Yes      31
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 30            Yes               Yes     Fiber optic  ...                   No
# 75            Yes                No              No  ...  No internet service
# 96            Yes                No             DSL  ...                  Yes
# 98            Yes                No             DSL  ...                  Yes
# 175           Yes               Yes     Fiber optic  ...                  Yes
# ...           ...               ...             ...  ...                  ...
# 7147          Yes               Yes             DSL  ...                  Yes
# 7169           No  No phone service             DSL  ...                   No
# 7200          Yes               Yes     Fiber optic  ...                   No
# 7228          Yes                No              No  ...  No internet service
# 7236          Yes                No              No  ...  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 30                     No                   No                   No
# 75    No internet service  No internet service  No internet service
# 96                     No                  Yes                   No
# 98                     No                  Yes                   No
# 175                   Yes                   No                  Yes
# ...                   ...                  ...                  ...
# 7147                   No                   No                   No
# 7169                   No                   No                  Yes
# 7200                   No                   No                   No
# 7228  No internet service  No internet service  No internet service
# 7236  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 30                     No  Month-to-month              Yes
# 75    No internet service        Two year              Yes
# 96                     No        One year              Yes
# 98                     No  Month-to-month               No
# 175                   Yes        One year              Yes
# ...                   ...             ...              ...
# 7147                   No        One year              Yes
# 7169                   No  Month-to-month               No
# 7200                   No  Month-to-month              Yes
# 7228  No internet service        Two year              Yes
# 7236  No internet service  Month-to-month              Yes
#
#                   PaymentMethod Charges_Monthly  Charges_Total
# 30    Bank transfer (automatic)           79.00         929.30
# 75      Credit card (automatic)           19.90        1355.10
# 96             Electronic check           58.75        1696.20
# 98      Credit card (automatic)           59.90         287.85
# 175   Bank transfer (automatic)          103.15        6792.45
# ...                         ...             ...            ...
# 7147               Mailed check           54.25         773.20
# 7169  Bank transfer (automatic)           40.65        2070.75
# 7200           Electronic check           76.25         684.85
# 7228  Bank transfer (automatic)           19.25        1372.90
# 7236               Mailed check           19.55         658.95
#
# [224 rows x 21 columns]

# %%
telecom['Churn'] = telecom['Churn'].replace('', 'No')

# %%
telecom.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod Charges_Monthly  Charges_Total
# 0              Yes      Mailed check            65.6         593.30
# 1               No      Mailed check            59.9         542.40
# 2              Yes  Electronic check            73.9         280.85
# 3              Yes  Electronic check            98.0        1237.85
# 4              Yes      Mailed check            83.9         267.40
#
# [5 rows x 21 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly as py
import plotly.express as px

# %%
telecom.sample(15)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 3045  4250-FDVOU   Yes  Female              0      No         No       6
# 2383  3336-JORSO   Yes  Female              1      No         No      33
# 3282  4587-NUKOX   Yes  Female              0      No         No       3
# 5195  7107-UBYKY    No  Female              0     Yes        Yes      35
# 3390  4710-FDUIZ   Yes    Male              0     Yes         No      56
# 4185  5760-WRAHC    No  Female              1      No         No      22
# 4938  6754-LZUKA    No    Male              0     Yes         No      61
# 1784  2535-PBCGC    No  Female              0     Yes         No      70
# 3838  5269-NRGDP    No    Male              0     Yes        Yes      42
# 4381  6016-LVTJQ    No  Female              0     Yes        Yes      34
# 4061  5569-OUICF   Yes  Female              1     Yes         No      28
# 6353  8748-HFWBO    No    Male              0     Yes        Yes      19
# 2317  3237-AJGEH   Yes  Female              0     Yes        Yes       3
# 904   1269-FOYWN    No    Male              0     Yes        Yes      44
# 950   1337-BOZWO    No    Male              0     Yes        Yes      18
#
#      PhoneService     MultipleLines InternetService  ...         OnlineBackup  \
# 3045          Yes                No             DSL  ...                  Yes
# 2383          Yes               Yes     Fiber optic  ...                  Yes
# 3282          Yes                No     Fiber optic  ...                  Yes
# 5195          Yes               Yes              No  ...  No internet service
# 3390          Yes               Yes     Fiber optic  ...                  Yes
# 4185          Yes                No             DSL  ...                   No
# 4938          Yes               Yes             DSL  ...                  Yes
# 1784           No  No phone service             DSL  ...                  Yes
# 3838          Yes                No             DSL  ...                   No
# 4381          Yes                No              No  ...  No internet service
# 4061          Yes               Yes     Fiber optic  ...                   No
# 6353          Yes                No              No  ...  No internet service
# 2317           No  No phone service             DSL  ...                   No
# 904           Yes                No              No  ...  No internet service
# 950            No  No phone service             DSL  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3045                   No                   No                   No
# 2383                  Yes                  Yes                  Yes
# 3282                   No                   No                   No
# 5195  No internet service  No internet service  No internet service
# 3390                   No                   No                  Yes
# 4185                  Yes                  Yes                   No
# 4938                  Yes                   No                  Yes
# 1784                  Yes                  Yes                  Yes
# 3838                  Yes                  Yes                  Yes
# 4381  No internet service  No internet service  No internet service
# 4061                   No                  Yes                  Yes
# 6353  No internet service  No internet service  No internet service
# 2317                   No                  Yes                   No
# 904   No internet service  No internet service  No internet service
# 950                   Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 3045                   No  Month-to-month               No
# 2383                  Yes  Month-to-month              Yes
# 3282                   No  Month-to-month              Yes
# 5195  No internet service  Month-to-month              Yes
# 3390                  Yes        One year               No
# 4185                  Yes  Month-to-month              Yes
# 4938                  Yes        Two year               No
# 1784                  Yes        Two year               No
# 3838                  Yes        One year               No
# 4381  No internet service  Month-to-month               No
# 4061                  Yes  Month-to-month              Yes
# 6353  No internet service        One year               No
# 2317                   No  Month-to-month              Yes
# 904   No internet service        One year               No
# 950                    No        One year               No
#
#                   PaymentMethod Charges_Monthly  Charges_Total
# 3045           Electronic check           56.25         389.10
# 2383           Electronic check          110.45        3655.45
# 3282           Electronic check           79.10         246.50
# 5195           Electronic check           25.75         882.55
# 3390    Credit card (automatic)          100.30        5614.45
# 4185               Mailed check           69.75        1545.40
# 4938  Bank transfer (automatic)           80.90        4932.50
# 1784  Bank transfer (automatic)           64.55        4504.90
# 3838           Electronic check           73.15        3088.25
# 4381               Mailed check           20.65         716.40
# 4061    Credit card (automatic)          101.30        2812.20
# 6353               Mailed check           19.90         357.70
# 2317               Mailed check           31.00          95.05
# 904   Bank transfer (automatic)           20.00         860.85
# 950     Credit card (automatic)           46.40         812.40
#
# [15 rows x 21 columns]

# %%
telecom = telecom.drop(['customerID'], axis=1)

# %%
telecom['Charges_Daily'] = telecom['Charges_Monthly'] / 30

# %%
telecom.head()
# Out:
#   Churn  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    No  Female              0     Yes        Yes       9          Yes
# 1    No    Male              0      No         No       9          Yes
# 2   Yes    Male              0      No         No       4          Yes
# 3   Yes    Male              1     Yes         No      13          Yes
# 4   Yes  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1           Yes             DSL             No  ...               No
# 2            No     Fiber optic             No  ...              Yes
# 3            No     Fiber optic             No  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes              No        One year              Yes
# 1          No          No             Yes  Month-to-month               No
# 2          No          No              No  Month-to-month              Yes
# 3          No         Yes             Yes  Month-to-month              Yes
# 4         Yes         Yes              No  Month-to-month              Yes
#
#       PaymentMethod Charges_Monthly  Charges_Total  Charges_Daily
# 0      Mailed check            65.6         593.30       2.186667
# 1      Mailed check            59.9         542.40       1.996667
# 2  Electronic check            73.9         280.85       2.463333
# 3  Electronic check            98.0        1237.85       3.266667
# 4      Mailed check            83.9         267.40       2.796667
#
# [5 rows x 21 columns]

# %% [markdown]
# #📊 Carga y análisis

# %%
telecom.describe()
# Out:
#        SeniorCitizen       tenure  Charges_Monthly  Charges_Total  \
# count      7256.0000  7256.000000      7256.000000    7256.000000
# mean          0.1629    32.395535        64.755423    2280.634213
# std           0.3693    24.558067        30.125739    2268.632997
# min           0.0000     1.000000        18.250000      18.800000
# 25%           0.0000     9.000000        35.450000     400.225000
# 50%           0.0000    29.000000        70.300000    1391.000000
# 75%           0.0000    55.000000        89.900000    3785.300000
# max           1.0000    72.000000       118.750000    8684.800000
#
#        Charges_Daily
# count    7256.000000
# mean        2.158514
# std         1.004191
# min         0.608333
# 25%         1.181667
# 50%         2.343333
# 75%         2.996667
# max         3.958333

# %% [markdown]
# ##Grafica Porcentaje de cliente de permanencia y cancelacion.

# %%
fig, ax = plt.subplots(figsize=(8, 6))

churn_counts = telecom['Churn'].value_counts()
churn_porcentage = telecom['Churn'].value_counts(normalize=True) * 100

bars = ax.bar(churn_counts.index, churn_counts.values, color =['skyblue', 'red'])
ax.set_title('Porcentaje de clientes de permanencia y cancelacion', loc ='left', fontsize = 18)
ax.set_xlabel('Churn')
ax.set_ylabel('Cantidad de clientes', fontsize = 14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
plt.xticks(['No', 'Yes'], ['Permanecen', 'Abandonaron'])

labels = [f'{p:.1f}%' for p in churn_porcentage[churn_counts.index]]

ax.bar_label(bars, labels=labels, padding=3, fontsize=12)

ax.grid(linestyle='--')
plt.tight_layout()

plt.show()

# %% [markdown]
# ##Grafica Comparacion de clientes que abandonaron por tipo de contrato

# %%
# Agrupar por tipo de contrato y Churn, y contar ocurrencias
contract_churn = telecom.groupby(['Contract', 'Churn']).size().unstack(fill_value=0)

ax = contract_churn.plot(kind='bar', figsize=(10, 6), color=['blue', 'red'])

# Etiquetas y título
ax.set_title('Comparación de clientes que abandonaron por Tipo de Contrato', loc='left', fontsize=18)
ax.set_xlabel('Tipo de Contrato', fontsize=14)
ax.set_ylabel('Cantidad de Clientes', fontsize=14)
ax.tick_params(axis='x', rotation=0) # Rotar etiquetas del eje x si es necesario
ax.legend(title='Churn', labels=['Permanecen', 'Abandonaron'])

# Mostrar el porcentaje en las barras
for container in ax.containers:
    ax.bar_label(container, fmt='%d')

ax.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##'Distribución de Clientes que Permanecen por Tipo de Contrato y Meses de permanencia.

# %%
# prompt: de acuerdo a la grafica anterior neceisto una grafica de barras por tipo de contrato de los que permanecen con la columna  tenure

# Filtrar los clientes que permanecen (Churn == 'No')
telecom_permanecen = telecom[telecom['Churn'] == 'No'].copy()

# Crear bins para la columna 'tenure'
# Puedes ajustar los bins según la distribución de tus datos
bins = [0, 12, 24, 36, 48, 60, 72]
labels = ['0-12', '13-24', '25-36', '37-48', '49-60', '61-72']

telecom_permanecen['tenure_group'] = pd.cut(telecom_permanecen['tenure'], bins=bins, labels=labels, right=True, include_lowest=True)

# Agrupar por tipo de contrato y grupo de 'tenure' y contar ocurrencias
contract_tenure = telecom_permanecen.groupby(['Contract', 'tenure_group']).size().unstack(fill_value=0)

# Crear la gráfica de barras apiladas
ax = contract_tenure.plot(kind='bar', figsize=(12, 7), colormap='viridis')

# Etiquetas y título
ax.set_title('Distribución de Clientes que Permanecen por Tipo de Contrato y Tenure', loc='left', fontsize=18)
ax.set_xlabel('Tipo de Contrato', fontsize=14)
ax.set_ylabel('Cantidad de Clientes', fontsize=14)
ax.tick_params(axis='x', rotation=0)
ax.legend(title='Tenure (Meses)')

# Mostrar el número de clientes en cada segmento de barra
for container in ax.containers:
    ax.bar_label(container, fmt='%d', label_type='edge', fontsize=8)

ax.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-70-3582585778>:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   contract_tenure = telecom_permanecen.groupby(['Contract', 'tenure_group']).size().unstack(fill_value=0)

# %% [markdown]
# ##Grafica de Metodos de pagos por clientes que abandonaron

# %%
# prompt: de acuerdo a la grafica anterior neceisto graficar tipo de contrato de los que abandonaros cual es el PaymentMethod

# Filtrar el DataFrame para obtener solo los clientes que abandonaron ('Yes')
churned_customers = telecom[telecom['Churn'] == 'Yes']

# Contar la distribución de PaymentMethod para estos clientes
payment_method_counts_churned = churned_customers['PaymentMethod'].value_counts()

# Crear el gráfico de barras
fig, ax = plt.subplots(figsize=(10, 6))

bars = ax.bar(payment_method_counts_churned.index, payment_method_counts_churned.values, color=sns.color_palette("viridis", len(payment_method_counts_churned)))

ax.set_title('Métodos de Pago para Clientes que Abandonaron', loc='left', fontsize=18)
ax.set_xlabel('Método de Pago', fontsize=14)
ax.set_ylabel('Cantidad de Clientes', fontsize=14)
ax.tick_params(axis='x', rotation=45, labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# Agregar las etiquetas de valor en las barras
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval, int(yval), va='bottom', ha='center', fontsize=10) # va: vertical alignment, ha: horizontal alignment

ax.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
# prompt: grafica comparativa entre  columna churn que abandonaron por la columna InternetService

# ##Grafica Comparativa entre columna Churn y columna InternetService
internet_churn = telecom.groupby(['InternetService', 'Churn']).size().unstack(fill_value=0)

ax = internet_churn.plot(kind='bar', figsize=(10, 6), color=['blue', 'red'])

ax.set_title('Comparativa de clientes que abandonaron por Servicio de Internet', loc='left', fontsize=18)
ax.set_xlabel('Servicio de Internet', fontsize=14)
ax.set_ylabel('Cantidad de Clientes', fontsize=14)
ax.tick_params(axis='x', rotation=0)
ax.legend(title='Churn', labels=['Permanecen', 'Abandonaron'])

for container in ax.containers:
    ax.bar_label(container, fmt='%d')

ax.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
# prompt: grafica comparativa entre  columna Churn que abandonaron por la columna PaperlessBilling

# Gráfico Comparativa entre Churn y PaperlessBilling
paperless_churn = telecom.groupby(['PaperlessBilling', 'Churn']).size().unstack(fill_value=0)

ax = paperless_churn.plot(kind='bar', figsize=(8, 6), color=['skyblue', 'salmon'])

ax.set_title('Comparativa de Churn por Facturación Electrónica', loc='left', fontsize=18)
ax.set_xlabel('Facturación Electrónica (Paperless Billing)', fontsize=14)
ax.set_ylabel('Cantidad de Clientes', fontsize=14)
ax.tick_params(axis='x', rotation=0)
ax.legend(title='Churn', labels=['Permanecen', 'Abandonaron'])
plt.xticks([0, 1], ['No', 'Yes']) # Asumiendo que los índices 0 y 1 corresponden a 'No' y 'Yes'

for container in ax.containers:
    ax.bar_label(container, fmt='%d')

ax.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()

# %%
telecom.head()
# Out:
#   Churn  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    No  Female              0     Yes        Yes       9          Yes
# 1    No    Male              0      No         No       9          Yes
# 2   Yes    Male              0      No         No       4          Yes
# 3   Yes    Male              1     Yes         No      13          Yes
# 4   Yes  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL             No  ...               No
# 1           Yes             DSL             No  ...               No
# 2            No     Fiber optic             No  ...              Yes
# 3            No     Fiber optic             No  ...              Yes
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes              No        One year              Yes
# 1          No          No             Yes  Month-to-month               No
# 2          No          No              No  Month-to-month              Yes
# 3          No         Yes             Yes  Month-to-month              Yes
# 4         Yes         Yes              No  Month-to-month              Yes
#
#       PaymentMethod Charges_Monthly  Charges_Total  Charges_Daily
# 0      Mailed check            65.6         593.30       2.186667
# 1      Mailed check            59.9         542.40       1.996667
# 2  Electronic check            73.9         280.85       2.463333
# 3  Electronic check            98.0        1237.85       3.266667
# 4      Mailed check            83.9         267.40       2.796667
#
# [5 rows x 21 columns]

# %% [markdown]
# #📄Informe final

# %% [markdown]
# **Diccionario de datos**
#
# customerID: número de identificación único de cada cliente
#
# Churn: si el cliente dejó o no la empresa
#
# gender: género (masculino y femenino)
#
# SeniorCitizen: información sobre si un cliente tiene o no una edad igual o mayor a 65 años
#
# Partner: si el cliente tiene o no una pareja
#
# Dependents: si el cliente tiene o no dependientes
#
# tenure: meses de contrato del cliente
#
# PhoneService: suscripción al servicio telefónico
#
# MultipleLines: suscripción a más de una línea telefónica
#
# InternetService: suscripción a un proveedor de internet
#
# OnlineSecurity: suscripción adicional de seguridad en línea
#
# OnlineBackup: suscripción adicional de respaldo en línea
#
# DeviceProtection: suscripción adicional de protección del dispositivo
#
# TechSupport: suscripción adicional de soporte técnico, menor tiempo de espera
#
# StreamingTV: suscripción de televisión por cable
#
# StreamingMovies: suscripción de streaming de películas
#
# Contract: tipo de contrato
#
# PaperlessBilling: si el cliente prefiere recibir la factura en línea
#
# PaymentMethod: forma de pago
#
# Charges.Monthly: total de todos los servicios del cliente por mes
#
# Charges.Total: total gastado por el cliente
